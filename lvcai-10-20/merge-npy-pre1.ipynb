# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# %matplotlib inline

# %%
x_train_base_dir = 'F:/lvcai/guangdong_round2_train_20181011/splited-squrenpy/train/X/'
y_train_base_dir = 'F:/lvcai/guangdong_round2_train_20181011/splited-squrenpy/train/Y/'

x_val_base_dir = 'F:/lvcai/guangdong_round2_train_20181011/splited-squrenpy/val/X/'
y_val_base_dir = 'F:/lvcai/guangdong_round2_train_20181011/splited-squrenpy/val/Y/'

# %%
x_train_list = os.listdir(x_train_base_dir)
x_train_list
# Out:
# ['0_X_train.npy',
#  '10_X_train.npy',
#  '1_X_train.npy',
#  '2_X_train.npy',
#  '3_X_train.npy',
#  '4_X_train.npy',
#  '5_X_train.npy',
#  '6_X_train.npy',
#  '7_X_train.npy',
#  '8_X_train.npy',
#  '9_X_train.npy']

# %%
y_train_list = os.listdir(y_train_base_dir)
y_train_list
# Out:
# ['0_Y_train.npy',
#  '10_Y_train.npy',
#  '1_Y_train.npy',
#  '2_Y_train.npy',
#  '3_Y_train.npy',
#  '4_Y_train.npy',
#  '5_Y_train.npy',
#  '6_Y_train.npy',
#  '7_Y_train.npy',
#  '8_Y_train.npy',
#  '9_Y_train.npy']

# %%
x_val_list = os.listdir(x_val_base_dir)
x_val_list
# Out:
# ['0_X_val.npy',
#  '10_X_val.npy',
#  '1_X_val.npy',
#  '2_X_val.npy',
#  '3_X_val.npy',
#  '4_X_val.npy',
#  '5_X_val.npy',
#  '6_X_val.npy',
#  '7_X_val.npy',
#  '8_X_val.npy',
#  '9_X_val.npy']

# %%
y_val_list = os.listdir(y_val_base_dir)
y_val_list
# Out:
# ['0_Y_val.npy',
#  '10_Y_val.npy',
#  '1_Y_val.npy',
#  '2_Y_val.npy',
#  '3_Y_val.npy',
#  '4_Y_val.npy',
#  '5_Y_val.npy',
#  '6_Y_val.npy',
#  '7_Y_val.npy',
#  '8_Y_val.npy',
#  '9_Y_val.npy']

# %%
a=np.load(x_train_base_dir + x_train_list[0])
b=np.load(x_train_base_dir + x_train_list[1])

# %%
print(a.shape)
print(b.shape)
# Out:
# (312, 480, 480, 3)
# (183, 480, 480, 3)

# %%
a=np.vstack((a,b))

# %%
a.shape
# Out:
# (495, 480, 480, 3)

# %%
plt.imshow(a[311,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(a[312,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### 合并X_TRAIN

# %%
x_train_list = os.listdir(x_train_base_dir)
x_train_list
# Out:
# ['0_X_train.npy',
#  '10_X_train.npy',
#  '1_X_train.npy',
#  '2_X_train.npy',
#  '3_X_train.npy',
#  '4_X_train.npy',
#  '5_X_train.npy',
#  '6_X_train.npy',
#  '7_X_train.npy',
#  '8_X_train.npy',
#  '9_X_train.npy']

# %%
import gc

# %%
for i in range(11):
    print(x_train_list[i])
    if i==0:
        a=np.load(x_train_base_dir + x_train_list[0])
        b=np.load(x_train_base_dir + x_train_list[1])
        X=np.vstack((a,b))
        del a
        del b
        gc.collect()
    elif i==1:
        continue
    else:
        a=np.load(x_train_base_dir + x_train_list[i])
        X=np.vstack((X,a))
        del a
        gc.collect()
# Out:
# 0_X_train.npy
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-c506c36869c9> in <module>()
#       4         a=np.load(x_train_base_dir + x_train_list[0])
#       5         b=np.load(x_train_base_dir + x_train_list[1])
# ----> 6         X=np.vstack((a,b))
#       7         del a
#       8         del b
#
# E:\Anaconda\envs\tensorflow\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     235
#     236     """
# --> 237     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     238
#     239 def hstack(tup):
#
# MemoryError:

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-270dd209b8a9> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
for i in range(11):
    print(y_train_list[i])
    if i==0:
        a=np.load(y_train_base_dir + y_train_list[0])
        b=np.load(y_train_base_dir + y_train_list[1])
        X=np.vstack((a,b))
        del a
        del b
        gc.collect()
    elif i==1:
        continue
    else:
        a=np.load(y_train_base_dir + y_train_list[i])
        X=np.vstack((X,a))
        del a
        gc.collect()
# Out:
# 0_Y_train.npy
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-27-7c288a4aef7d> in <module>()
#       4         a=np.load(y_train_base_dir + y_train_list[0])
#       5         b=np.load(y_train_base_dir + y_train_list[1])
# ----> 6         X=np.vstack((a,b))
#       7         del a
#       8         del b
#
# E:\Anaconda\envs\tensorflow\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     235
#     236     """
# --> 237     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     238
#     239 def hstack(tup):
#
# MemoryError:

# %% [markdown]
# #### 手动扩充合并

# %%
a=np.load(x_train_base_dir + x_train_list[0])
b=np.load(x_train_base_dir + x_train_list[1])
X=np.vstack((a,b))
