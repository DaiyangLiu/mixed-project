# %%
import numpy as np
#import random

# %%
list1=[1,2,3,4,5,6,7,8]
list2=[11,12,13,14,15,16,17,18]

# %%
permutation = np.random.permutation(8)

# %%
permutation
# Out:
# array([2, 0, 5, 4, 3, 7, 1, 6])

# %%
from sklearn.utils import shuffle

# %%
x,y = shuffle(list1,list2,random_state=0)

# %%
x
# Out:
# [7, 3, 2, 8, 4, 1, 6, 5]

# %%
y
# Out:
# [17, 13, 12, 18, 14, 11, 16, 15]

# %%
X = np.array([[1., 0.], [2., 1.], [0., 0.]])
y = np.array([[0, 0], [1, 0], [1, 1]])

# %%
x,y = shuffle(X,y,random_state=1)

# %%
x
# Out:
# array([[ 1.,  0.],
#        [ 0.,  0.],
#        [ 2.,  1.]])

# %%
y
# Out:
# array([[0, 0],
#        [1, 1],
#        [1, 0]])

# %%
base_dir='F:/lvcai/guangdong_round2_train_20181011/squarenpy/'

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# %matplotlib inline

# %%
npy_list=os.listdir(base_dir)

# %%
X=np.load(base_dir+npy_list[0])
Y=np.load(base_dir+npy_list[1])

# %%
x,y = shuffle(X,Y,random_state=2011)

# %%
num=x.shape[0]
num
# Out:
# 390

# %%
tag=int(0.8*num)

# %%
a=x[:tag,:,:,:]
b=x[tag:,:,:,:]

# %%
a.shape
# Out:
# (312, 480, 480, 3)

# %%
plt.imshow(a[311,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
b.shape
# Out:
# (78, 480, 480, 3)

# %%
plt.imshow(b[0,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(16,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x[i,:,:,0])

# %%
plt.figure(figsize=(16,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(y[i,:,:,0])
