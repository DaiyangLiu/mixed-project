# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# %matplotlib inline

# %%
base_dir='F:/lvcai/guangdong_round2_train_20181011/merged-squarenpy/'

# %%
merged_list = os.listdir(base_dir)
merged_list
# Out:
# ['merged_X_train.npy',
#  'merged_X_val.npy',
#  'merged_Y_train.npy',
#  'merged_Y_val.npy']

# %%
x_train=np.load(base_dir+merged_list[0])
x_train.shape
# Out:
# (2399, 480, 480, 3)

# %%
y_train=np.load(base_dir+merged_list[2])
y_train.shape
# Out:
# (2399, 480, 480, 10)

# %%
plt.figure(figsize=(16,5))
for  i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[2200+i])

# %%
plt.figure(figsize=(16,5))
for  i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(y_train[2200+i,:,:,7])
