# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/guangdong_round1_train2_20180916/normal/'
file_list = os.listdir(base_dir)[:32]

plt.figure(figsize=(20,10))
for index in range(32):
    plt.subplot(4,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    threshold,s = cv2.threshold(s,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#     r = cv2.adaptiveThreshold(r, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_OTSU, 17, 0)
    plt.imshow(s, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/guangdong_round1_train2_20180916/normal/'
file_list = os.listdir(base_dir)[:32]

plt.figure(figsize=(20,10))
for index in range(32):
    plt.subplot(4,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    b, g, r = cv2.split(img)
    
    threshold,r = cv2.threshold(r,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#     r = cv2.adaptiveThreshold(r, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_OTSU, 17, 0)
    
    plt.imshow(r, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    b, g, r = cv2.split(img)
    
    threshold,r = cv2.threshold(r,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#     r = cv2.adaptiveThreshold(r, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_OTSU, 17, 0)
    
    plt.imshow(r, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    threshold,s = cv2.threshold(s,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#     r = cv2.adaptiveThreshold(r, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_OTSU, 17, 0)
    plt.imshow(s, cmap='gray')

# %% [markdown]
# #### https://blog.csdn.net/sinat_21258931/article/details/61418681
# #### 自适应阈值二值化示例
# #### 结果感觉那个th1效果还不错

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('F:/lvcai/normal/20180911104058.jpg',0)

img = cv2.medianBlur(img,5)
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)

th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# #### 大规模测试

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index],0)
    img = cv2.resize(img,(448,336))
    img = cv2.medianBlur(img,5)
    ret,th1 = cv2.threshold(img,150,255,cv2.THRESH_BINARY)
    plt.imshow(th1,'gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index],0)
    img = cv2.resize(img,(448,336))
    img = cv2.medianBlur(img,5)
    th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
    plt.imshow(th2,'gray')

# %% [markdown]
# #### 查看各个通道中，哪一个通道最有做阈值化的潜力

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    plt.imshow(s, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/guangdong_round1_train2_20180916/normal/'
file_list = os.listdir(base_dir)[:32]

plt.figure(figsize=(20,10))
for index in range(32):
    plt.subplot(4,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    plt.imshow(h, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/guangdong_round1_train2_20180916/normal/'
file_list = os.listdir(base_dir)[:32]

plt.figure(figsize=(20,10))
for index in range(32):
    plt.subplot(4,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    plt.imshow(v, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    b, g, r = cv2.split(img)
    plt.imshow(b, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    b, g, r = cv2.split(img)
    plt.imshow(g, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    b, g, r = cv2.split(img)
    plt.imshow(r, cmap='gray')

# %% [markdown]
# #### 结论：还是 hsv中的S通道最有潜力

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    s = cv2.medianBlur(s,5)
    ret,th1 = cv2.threshold(s,135,255,cv2.THRESH_BINARY)
    #th2 = cv2.adaptiveThreshold(s,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
           # cv2.THRESH_BINARY,11,2)
    plt.imshow(th1, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    s = cv2.medianBlur(s,5)
    threshold,s = cv2.threshold(s,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    plt.imshow(s, cmap='gray')

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    s = cv2.medianBlur(s,3)
    threshold,s = cv2.threshold(s,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    plt.imshow(s, cmap='gray')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('F:/lvcai/normal/20180911104058.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('F:/lvcai/normal/20180911104058.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# #### 平滑滤波改进OSTU

# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

base_dir = 'F:/lvcai/normal/'
file_list = os.listdir(base_dir)

plt.figure(figsize=(20,10))
for index in range(21):
    plt.subplot(3,8,index+1)
    
    img = cv2.imread(base_dir + file_list[index])
    img = cv2.resize(img,(448,336))
    
    dst = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    
    h, s, v = cv2.split(dst)
    
    s = cv2.blur(s,(10,10))
    threshold,s = cv2.threshold(s,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    plt.imshow(s, cmap='gray')
