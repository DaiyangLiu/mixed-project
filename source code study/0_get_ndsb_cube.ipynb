# %%
import dicom
import logging
import glob
import os
import numpy as np
def load_patient(src_dir):
    print("dicom_path:" ,src_dir)
    
    src_dir_dcm = glob.glob(src_dir+'/*dcm')
    
    slices = []
    for s in src_dir_dcm:
        dcmsize=os.path.getsize(s)
        if dcmsize > 525000:
            slices.append(dicom.read_file(s))
            
    slices.sort(key=lambda x: int(x.InstanceNumber))
    
    try:
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2]-slices[1].ImagePositionPatient[2])
    except Exception as e:
        logging.exception(e)
        slice_thickness=np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
        
    for s in slices:
        s.SliceThickness = slice_thickness
        
    return slices

# %%
import glob
src_dir = 'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e'
src_dir_dcm = glob.glob(src_dir+'/*dcm')

# %%
src_dir_dcm
# Out:
# ['F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\034673134cbef5ea15ff9e0c8090500a.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\0484f5a7f55eb7b6743cadaffcce586d.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\053a0460fb45227bd8e0e7b514a71e8e.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\0678ae61b7c56dfaf35477f6d01a6ffc.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\06ba0baeb0f26fb7aed5249eebbb77a9.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\0791f624c2f313bfe490ac940947977e.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\08eb3a007acc90a45b6e1b92fb479adc.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\090173a7ed57a872b62fd7c0b1d24be5.dcm',
#  'F:/kaggledata/stage1/stage1/00cba091fa4ad62cc3200a657aeb957e\\0a291d1b12b86213d813e3796f14b329.dcm',
# ...

# %%
s=src_dir_dcm[0]

# %%
os.path.getsize(s)
# Out:
# 525448

# %%
dicom.read_file(s)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.249139163741242644304020243485943527041
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0020) Patient ID                          LO: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.86208730140539712382771890501772734277950692397709007305473
# (0020, 000e) Series Instance UID                 UI: 2.25.11575877329635228925808596800269974740893519451784626046614
# (0020, 0011) Series Number                       IS: '3'
# ...

# %%
slices = []
for s in src_dir_dcm:
    dcmsize=os.path.getsize(s)
    if dcmsize > 525000:
        slices.append(dicom.read_file(s))

# %%
slices
# Out:
# [(0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.249139163741242644304020243485943527041
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0020) Patient ID                          LO: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.86208730140539712382771890501772734277950692397709007305473
# (0020, 000e) Series Instance UID                 UI: 2.25.11575877329635228925808596800269974740893519451784626046614
# (0020, 0011) Series Number                       IS: '3'
# ...

# %%
slices.sort(key=lambda x: int(x.InstanceNumber))

# %%
slices
# Out:
# [(0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113654.2.55.294523283581565931298765832966512471268
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0010) Patient's Name                      PN: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0020) Patient ID                          LO: '00cba091fa4ad62cc3200a657aeb957e'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 000d) Study Instance UID                  UI: 2.25.86208730140539712382771890501772734277950692397709007305473
# (0020, 000e) Series Instance UID                 UI: 2.25.11575877329635228925808596800269974740893519451784626046614
# (0020, 0011) Series Number                       IS: '3'
# ...

# %%
try:
    slice_thickness = np.abs(slices[0].ImagePositionPatient[2]-slices[1].ImagePositionPatient[2])
except Exception as e:
    logging.exception(e)
    slice_thickness=np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
        
for s in slices:
    s.SliceThickness = slice_thickness

# %%
slice_thickness
# Out:
# 2.5

# %%
a=[[1 ,2],[2 ,3],[4 ,5]]

# %%
b=np.stack([x for x in a])

# %%
b
# Out:
# array([[1, 2],
#        [2, 3],
#        [4, 5]])
